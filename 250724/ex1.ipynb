# %% [markdown]
# ## Exercise 1
# ### - Given a text file of 10,000 lines, each line contains a pair of (key,value)
# ### - Calculate the average value for each key
# ### - Apply groupByKey() and reuceByKey() functions
# Compare?

# %% [markdown]
# ### Initialize Spark

# %%
import findspark
findspark.init()

# %% [markdown]
# ### Generate text file with 10,000 lines of (key,value)

# %%
# generate a text file of 10,000 lines, each line contains a pair of (key, value) 
# where key is a random integer between 1 and 1000, and value is a random integer between 1 and 10000
# the key-value pairs are separated by a tab character
import random
num_lines = 10000

file_name = "data/keyValue.txt"
with open(file_name, "w+") as f:
    for i in range(num_lines):
        key = random.randint(1, 1000)
        value = random.randint(1, 10000)
        f.write(f"{key},{value}\n")

print(f"Generated {num_lines} lines of key-value pairs in {file_name}")
# Out:
# Generated 10000 lines of key-value pairs in data/keyValue.txt

# %% [markdown]
# **Create a Spark Session**

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("KeyValuePairs") \
    .getOrCreate()

# %% [markdown]
# **Load the dataset**

# %%
keyValue_rdd = spark.sparkContext.textFile("data/keyValue.txt")

# %%
keyValue_rdd.take(5)
# Out:
# ['18,3159', '129,6019', '220,1520', '410,1511', '370,3914']

# %% [markdown]
# **Parse the pairs**

# %%
pairs = keyValue_rdd.map(lambda line: tuple(map(int, line.split(','))))

# %%
pairs.take(10)
# Out:
# [(18, 3159),
#  (129, 6019),
#  (220, 1520),
#  (410, 1511),
#  (370, 3914),
#  (879, 2951),
#  (899, 6874),
#  (163, 5113),
#  (171, 5550),
#  (779, 6385)]

# %% [markdown]
# #### Calculate average value for each key

# %%
# Group by key
grouped = pairs.groupByKey()

averages_groupByKey = grouped.mapValues(lambda values: sum(values) / len(values))

# Collect and print the results
averages_groupByKey_result = averages_groupByKey.collect()
print("Averages using groupByKey():", averages_groupByKey_result)
# Out:
# Averages using groupByKey(): [(18, 4878.214285714285), (220, 4342.833333333333), (410, 4575.0), (370, 4966.0), (268, 7868.857142857143), (776, 4523.642857142857), (102, 4956.833333333333), (574, 4548.636363636364), (668, 5812.0), (740, 5214.333333333333), (616, 3479.3636363636365), (778, 6641.0), (920, 5305.666666666667), (422, 5734.777777777777), (674, 4716.0), (470, 4388.714285714285), (166, 4059.8333333333335), (484, 4850.7), (112, 6428.888888888889), (904, 4973.666666666667), (34, 7371.166666666667), (332, 4376.866666666667), (320, 5016.3), (734, 4304.166666666667), (156, 5929.0), (882, 4843.714285714285), (896, 5023.133333333333), (468, 3701.4285714285716), (780, 5126.538461538462), (692, 4573.0), (218, 5468.3125), (252, 4976.5), (572, 5284.5), (38, 4367.846153846154), (750, 4777.928571428572), (730, 5898.428571428572), (412, 4869.2), (506, 4506.5), (988, 3946.5833333333335), (230, 5190.555555555556), (500, 6073.090909090909), (908, 4091.222222222222), (636, 4569.461538461538), (96, 3568.777777777778), (164, 3754.1176470588234), (554, 3768.625), (714, 4764.111111111111), (20, 2696.5714285714284), (700, 6608.090909090909), (406, 5719.4), (764, 4853.454545454545), (804, 5388.916666666667), (402, 6260.625), (354, 4019.0625), (696, 4694.375), (624, 3516.6666666666665), (768, 3596.7272727272725), (28, 5382.1), (366, 4401.75), (862, 6657.153846153846), (304, 5001.909090909091), (846, 6136.5), (214, 7076.0), (662, 6266.2), (934, 4612.545454545455), (182, 5275.444444444444), (598, 5658.64705882353), (984, 3664.285714285714), (970, 5622.666666666667), (250, 6248.6875), (782, 5385.785714285715), (828, 3496.6), (190, 6209.2), (492, 5266.571428571428), (864, 3958.4), (134, 4449.333333333333), (376, 5725.333333333333), (942, 5999.875), (26, 4361.611111111111), (340, 4839.5), (328, 6005.4), (520, 4645.8), (24, 3540.2), (738, 5431.4), (540, 4242.888888888889), (52, 5932.588235294118), (790, 5304.857142857143), (756, 5035.166666666667), (312, 6011.142857142857), (132, 4076.818181818182), (382, 5383.1578947368425), (952, 4711.277777777777), (342, 5876.545454545455), (254, 3516.375), (488, 6101.75), (760, 5669.583333333333), (480, 6360.545454545455), (400, 4325.0), (302, 4911.2307692307695), (264, 4474.888888888889), (240, 5436.333333333333), (136, 4616.888888888889), (974, 5177.555555555556), (206, 4327.5), (308, 5148.166666666667), (248, 4941.75), (640, 5019.555555555556), (522, 2507.0), (638, 7019.777777777777), (594, 7191.5), (14, 4741.333333333333), (666, 4629.214285714285), (720, 4953.2), (464, 4135.727272727273), (10, 5468.090909090909), (686, 4432.375), (982, 4124.875), (654, 4654.692307692308), (178, 7477.2), (918, 3782.3333333333335), (388, 4502.125), (108, 3571.625), (498, 4143.8), (246, 4673.666666666667), (512, 4631.25), (130, 4348.846153846154), (8, 6180.083333333333), (306, 5392.0), (338, 4616.2307692307695), (912, 8156.0), (810, 4267.076923076923), (704, 6307.5), (570, 5143.636363636364), (86, 5391.428571428572), (534, 5107.222222222223), (842, 5407.545454545455), (344, 6937.833333333333), (84, 5722.181818181818), (742, 4732.0), (808, 3730.1428571428573), (818, 4512.133333333333), (802, 4065.5), (548, 4926.416666666667), (874, 4856.555555555556), (138, 4856.153846153846), (834, 5347.083333333333), (582, 3133.8571428571427), (510, 4970.210526315789), (786, 4156.5), (454, 5671.923076923077), (274, 5157.1), (646, 5051.0), (210, 6931.444444444444), (542, 4249.909090909091), (932, 5310.909090909091), (788, 4688.266666666666), (910, 5920.777777777777), (712, 4205.8), (706, 5948.625), (162, 4172.8125), (224, 4943.0), (466, 5702.4), (956, 4206.75), (434, 4749.363636363636), (840, 5469.75), (56, 4619.875), (964, 2128.3333333333335), (710, 4351.307692307692), (486, 5502.538461538462), (202, 4965.333333333333), (444, 5371.642857142857), (610, 4974.181818181818), (536, 6251.714285714285), (798, 4280.0), (980, 4996.636363636364), (54, 5180.857142857143), (242, 4425.3), (352, 5868.166666666667), (762, 6271.461538461538), (474, 3738.11111 ...

# %%
# Reduce by key
sum_counts = pairs.mapValues(lambda x: (x, 1))\
    .reduceByKey(lambda x, y: (x[0] + y[0], x[1] + y[1]))

averages_reduceByKey = sum_counts.mapValues(lambda x: x[0]/x[1])

averages_reduceByKey_result = averages_reduceByKey.collect()
print("Averages using reduceByKey():", averages_reduceByKey_result)
# Out:
# Averages using reduceByKey(): [(18, 4878.214285714285), (220, 4342.833333333333), (410, 4575.0), (370, 4966.0), (268, 7868.857142857143), (776, 4523.642857142857), (102, 4956.833333333333), (574, 4548.636363636364), (668, 5812.0), (740, 5214.333333333333), (616, 3479.3636363636365), (778, 6641.0), (920, 5305.666666666667), (422, 5734.777777777777), (674, 4716.0), (470, 4388.714285714285), (166, 4059.8333333333335), (484, 4850.7), (112, 6428.888888888889), (904, 4973.666666666667), (34, 7371.166666666667), (332, 4376.866666666667), (320, 5016.3), (734, 4304.166666666667), (156, 5929.0), (882, 4843.714285714285), (896, 5023.133333333333), (468, 3701.4285714285716), (780, 5126.538461538462), (692, 4573.0), (218, 5468.3125), (252, 4976.5), (572, 5284.5), (38, 4367.846153846154), (750, 4777.928571428572), (730, 5898.428571428572), (412, 4869.2), (506, 4506.5), (988, 3946.5833333333335), (230, 5190.555555555556), (500, 6073.090909090909), (908, 4091.222222222222), (636, 4569.461538461538), (96, 3568.777777777778), (164, 3754.1176470588234), (554, 3768.625), (714, 4764.111111111111), (20, 2696.5714285714284), (700, 6608.090909090909), (406, 5719.4), (764, 4853.454545454545), (804, 5388.916666666667), (402, 6260.625), (354, 4019.0625), (696, 4694.375), (624, 3516.6666666666665), (768, 3596.7272727272725), (28, 5382.1), (366, 4401.75), (862, 6657.153846153846), (304, 5001.909090909091), (846, 6136.5), (214, 7076.0), (662, 6266.2), (934, 4612.545454545455), (182, 5275.444444444444), (598, 5658.64705882353), (984, 3664.285714285714), (970, 5622.666666666667), (250, 6248.6875), (782, 5385.785714285715), (828, 3496.6), (190, 6209.2), (492, 5266.571428571428), (864, 3958.4), (134, 4449.333333333333), (376, 5725.333333333333), (942, 5999.875), (26, 4361.611111111111), (340, 4839.5), (328, 6005.4), (520, 4645.8), (24, 3540.2), (738, 5431.4), (540, 4242.888888888889), (52, 5932.588235294118), (790, 5304.857142857143), (756, 5035.166666666667), (312, 6011.142857142857), (132, 4076.818181818182), (382, 5383.1578947368425), (952, 4711.277777777777), (342, 5876.545454545455), (254, 3516.375), (488, 6101.75), (760, 5669.583333333333), (480, 6360.545454545455), (400, 4325.0), (302, 4911.2307692307695), (264, 4474.888888888889), (240, 5436.333333333333), (136, 4616.888888888889), (974, 5177.555555555556), (206, 4327.5), (308, 5148.166666666667), (248, 4941.75), (640, 5019.555555555556), (522, 2507.0), (638, 7019.777777777777), (594, 7191.5), (14, 4741.333333333333), (666, 4629.214285714285), (720, 4953.2), (464, 4135.727272727273), (10, 5468.090909090909), (686, 4432.375), (982, 4124.875), (654, 4654.692307692308), (178, 7477.2), (918, 3782.3333333333335), (388, 4502.125), (108, 3571.625), (498, 4143.8), (246, 4673.666666666667), (512, 4631.25), (130, 4348.846153846154), (8, 6180.083333333333), (306, 5392.0), (338, 4616.2307692307695), (912, 8156.0), (810, 4267.076923076923), (704, 6307.5), (570, 5143.636363636364), (86, 5391.428571428572), (534, 5107.222222222223), (842, 5407.545454545455), (344, 6937.833333333333), (84, 5722.181818181818), (742, 4732.0), (808, 3730.1428571428573), (818, 4512.133333333333), (802, 4065.5), (548, 4926.416666666667), (874, 4856.555555555556), (138, 4856.153846153846), (834, 5347.083333333333), (582, 3133.8571428571427), (510, 4970.210526315789), (786, 4156.5), (454, 5671.923076923077), (274, 5157.1), (646, 5051.0), (210, 6931.444444444444), (542, 4249.909090909091), (932, 5310.909090909091), (788, 4688.266666666666), (910, 5920.777777777777), (712, 4205.8), (706, 5948.625), (162, 4172.8125), (224, 4943.0), (466, 5702.4), (956, 4206.75), (434, 4749.363636363636), (840, 5469.75), (56, 4619.875), (964, 2128.3333333333335), (710, 4351.307692307692), (486, 5502.538461538462), (202, 4965.333333333333), (444, 5371.642857142857), (610, 4974.181818181818), (536, 6251.714285714285), (798, 4280.0), (980, 4996.636363636364), (54, 5180.857142857143), (242, 4425.3), (352, 5868.166666666667), (762, 6271.461538461538), (474, 3738.1111 ...

# %%
# Compare the results
groupByKey_dict = dict(averages_groupByKey_result)
reduceByKey_dict = dict(averages_reduceByKey_result)

comparison = [(key, groupByKey_dict[key], reduceByKey_dict[key]) for key in groupByKey_dict if groupByKey_dict[key] != reduceByKey_dict[key]]

if not comparison:
    print("The results are the same.")
else:
    print("Differences found:", comparison)
# Out:
# The results are the same.
