# %% [markdown]
# ## Exercise 1
# ### - Given a text file of 10,000 lines, each line contains a pair of (key,value)
# ### - Calculate the average value for each key
# ### - Apply groupByKey() and reuceByKey() functions
# Compare?

# %% [markdown]
# ### Initialize Spark

# %%
import findspark
findspark.init()

# %% [markdown]
# ### Generate text file with 10,000 lines of (key,value)

# %%
# generate a text file of 10,000 lines, each line contains a pair of (key, value) 
# where key is a random integer between 1 and 1000, and value is a random integer between 1 and 10000
# the key-value pairs are separated by a tab character
import random
num_lines = 10000

file_name = "data/keyValue.txt"
with open(file_name, "w") as f:
    for i in range(num_lines):
        key = random.randint(1, 1000)
        value = random.randint(1, 10000)
        f.write(f"{key},{value}\n")

print(f"Generated {num_lines} lines of key-value pairs in {file_name}")
# Out:
# Generated 10000 lines of key-value pairs in data/keyValue.txt

# %% [markdown]
# **Create a Spark Session**

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("KeyValuePairs") \
    .getOrCreate()

# %% [markdown]
# **Load the dataset**

# %%
keyValue_rdd = spark.sparkContext.textFile("data/keyValue.txt")

# %%
keyValue_rdd.take(5)
# Out:
# ['39,570', '619,4718', '255,5145', '618,4235', '3,5922']

# %% [markdown]
# **Parse the pairs**

# %%
pairs = keyValue_rdd.map(lambda line: tuple(map(int, line.split(','))))

# %%
pairs.take(10)
# Out:
# [(39, 570),
#  (619, 4718),
#  (255, 5145),
#  (618, 4235),
#  (3, 5922),
#  (850, 2862),
#  (630, 5102),
#  (198, 5764),
#  (220, 1117),
#  (535, 2086)]

# %% [markdown]
# #### Calculate average value for each key

# %%
# Group by key
grouped = pairs.groupByKey()

# %%
averages_groupByKey = grouped.mapValues(lambda values: sum(values) / len(values))

# %%
# Collect and print the results
averages_groupByKey_result = averages_groupByKey.collect()
print("Averages using groupByKey():", averages_groupByKey_result)
# Out:
# Averages using groupByKey(): [(618, 5802.9), (850, 2793.0), (630, 4732.25), (198, 6160.4), (220, 3873.0714285714284), (650, 5607.3), (142, 4902.777777777777), (730, 3856.5), (426, 5459.0), (272, 5827.181818181818), (616, 3673.4166666666665), (744, 5723.846153846154), (704, 5131.125), (840, 3159.5), (38, 4802.727272727273), (26, 5847.0625), (258, 4062.5), (658, 5612.714285714285), (964, 4736.7692307692305), (574, 3940.4285714285716), (86, 5831.833333333333), (340, 6871.6), (936, 3077.9), (876, 4626.714285714285), (494, 4754.9), (754, 5988.1), (674, 2733.25), (456, 4933.714285714285), (706, 4889.1875), (668, 6297.692307692308), (462, 6487.5), (642, 3883.7272727272725), (102, 5579.0), (608, 4133.0), (862, 5915.8), (300, 4220.692307692308), (686, 4990.692307692308), (122, 5169.666666666667), (108, 4725.857142857143), (306, 5164.25), (772, 4754.583333333333), (666, 4320.7), (30, 4641.571428571428), (210, 5472.533333333334), (334, 5684.3), (292, 5774.0), (314, 4699.153846153846), (416, 5307.125), (440, 4298.7), (160, 5180.0), (878, 6408.222222222223), (902, 4042.0833333333335), (92, 4333.375), (316, 4445.0), (260, 6562.090909090909), (882, 4127.571428571428), (792, 3445.625), (2, 2982.1111111111113), (148, 5330.3), (916, 5176.166666666667), (190, 5958.4), (886, 3731.777777777778), (410, 4575.461538461538), (556, 5792.4), (382, 4208.125), (810, 5198.875), (480, 4971.166666666667), (846, 5942.538461538462), (40, 4912.0), (578, 5983.538461538462), (442, 5341.375), (894, 6864.8), (942, 4229.357142857143), (196, 4805.588235294118), (856, 4221.2307692307695), (482, 6169.083333333333), (492, 5437.166666666667), (46, 5653.818181818182), (848, 4743.5), (604, 6057.0), (126, 4693.833333333333), (594, 5385.0), (392, 5220.777777777777), (682, 6120.692307692308), (166, 4060.9285714285716), (438, 4583.3), (464, 5658.666666666667), (476, 4616.125), (12, 6135.7), (958, 2881.0), (444, 5577.666666666667), (290, 2940.5555555555557), (104, 4351.25), (386, 4934.583333333333), (660, 3092.0), (874, 3727.5454545454545), (156, 3978.5555555555557), (376, 5208.923076923077), (356, 4992.1), (162, 3883.2727272727275), (294, 4246.727272727273), (418, 5324.666666666667), (188, 6187.428571428572), (282, 6551.833333333333), (992, 3639.0), (528, 6123.818181818182), (872, 5245.2307692307695), (424, 5994.5), (20, 6182.384615384615), (948, 6203.285714285715), (66, 6032.166666666667), (944, 6099.307692307692), (378, 3100.3333333333335), (952, 5833.9), (824, 4089.75), (152, 5543.3), (580, 4713.5), (398, 3972.1666666666665), (478, 4067.4545454545455), (6, 6578.1), (572, 4506.625), (826, 5632.428571428572), (308, 5895.818181818182), (264, 4761.6), (112, 5224.153846153846), (860, 5363.333333333333), (42, 4913.928571428572), (236, 2571.4444444444443), (868, 5481.571428571428), (110, 5016.7692307692305), (430, 4335.181818181818), (18, 5145.888888888889), (428, 6346.636363636364), (988, 5109.454545454545), (182, 5437.625), (788, 5687.111111111111), (234, 3592.5), (502, 5064.375), (726, 4297.583333333333), (728, 4653.666666666667), (804, 4788.25), (54, 5043.384615384615), (500, 5148.0625), (998, 3726.5714285714284), (434, 5670.0), (596, 5245.7692307692305), (486, 5187.615384615385), (994, 3085.7), (266, 4032.9375), (312, 4274.1), (90, 3873.9375), (680, 5328.454545454545), (834, 4953.076923076923), (648, 4910.0), (636, 5030.636363636364), (552, 4110.692307692308), (628, 5439.285714285715), (694, 4302.9), (984, 4980.375), (208, 6116.416666666667), (720, 4173.2), (422, 5096.9), (844, 4487.461538461538), (448, 5218.454545454545), (330, 3911.5555555555557), (714, 5301.2), (186, 4688.5), (326, 5135.181818181818), (842, 4537.846153846154), (358, 5463.615384615385), (228, 4888.571428571428), (338, 4804.0), (566, 2128.1428571428573), (506, 5807.714285714285), (560, 5318.0), (690, 5429.923076923077), (610, 4407.090909090909), (366, 4765.714285714285), (504, 4818.6), (460, 5035.142857142857), (496, 4206.294117647059), (412, 6438.5), (748, 5837.8), (562, 6019.090909090909), (62, 5301.461538 ...

# %%
# Reduce by key
sum_counts = pairs.mapValues(lambda x: (x, 1))\
    .reduceByKey(lambda x, y: (x[0] + y[0], x[1] + y[1]))

averages_reduceByKey = sum_counts.mapValues(lambda x: x[0]/x[1])

averages_reduceByKey_result = averages_reduceByKey.collect()
print("Averages using reduceByKey():", averages_reduceByKey_result)
# Out:
# Averages using reduceByKey(): [(618, 5802.9), (850, 2793.0), (630, 4732.25), (198, 6160.4), (220, 3873.0714285714284), (650, 5607.3), (142, 4902.777777777777), (730, 3856.5), (426, 5459.0), (272, 5827.181818181818), (616, 3673.4166666666665), (744, 5723.846153846154), (704, 5131.125), (840, 3159.5), (38, 4802.727272727273), (26, 5847.0625), (258, 4062.5), (658, 5612.714285714285), (964, 4736.7692307692305), (574, 3940.4285714285716), (86, 5831.833333333333), (340, 6871.6), (936, 3077.9), (876, 4626.714285714285), (494, 4754.9), (754, 5988.1), (674, 2733.25), (456, 4933.714285714285), (706, 4889.1875), (668, 6297.692307692308), (462, 6487.5), (642, 3883.7272727272725), (102, 5579.0), (608, 4133.0), (862, 5915.8), (300, 4220.692307692308), (686, 4990.692307692308), (122, 5169.666666666667), (108, 4725.857142857143), (306, 5164.25), (772, 4754.583333333333), (666, 4320.7), (30, 4641.571428571428), (210, 5472.533333333334), (334, 5684.3), (292, 5774.0), (314, 4699.153846153846), (416, 5307.125), (440, 4298.7), (160, 5180.0), (878, 6408.222222222223), (902, 4042.0833333333335), (92, 4333.375), (316, 4445.0), (260, 6562.090909090909), (882, 4127.571428571428), (792, 3445.625), (2, 2982.1111111111113), (148, 5330.3), (916, 5176.166666666667), (190, 5958.4), (886, 3731.777777777778), (410, 4575.461538461538), (556, 5792.4), (382, 4208.125), (810, 5198.875), (480, 4971.166666666667), (846, 5942.538461538462), (40, 4912.0), (578, 5983.538461538462), (442, 5341.375), (894, 6864.8), (942, 4229.357142857143), (196, 4805.588235294118), (856, 4221.2307692307695), (482, 6169.083333333333), (492, 5437.166666666667), (46, 5653.818181818182), (848, 4743.5), (604, 6057.0), (126, 4693.833333333333), (594, 5385.0), (392, 5220.777777777777), (682, 6120.692307692308), (166, 4060.9285714285716), (438, 4583.3), (464, 5658.666666666667), (476, 4616.125), (12, 6135.7), (958, 2881.0), (444, 5577.666666666667), (290, 2940.5555555555557), (104, 4351.25), (386, 4934.583333333333), (660, 3092.0), (874, 3727.5454545454545), (156, 3978.5555555555557), (376, 5208.923076923077), (356, 4992.1), (162, 3883.2727272727275), (294, 4246.727272727273), (418, 5324.666666666667), (188, 6187.428571428572), (282, 6551.833333333333), (992, 3639.0), (528, 6123.818181818182), (872, 5245.2307692307695), (424, 5994.5), (20, 6182.384615384615), (948, 6203.285714285715), (66, 6032.166666666667), (944, 6099.307692307692), (378, 3100.3333333333335), (952, 5833.9), (824, 4089.75), (152, 5543.3), (580, 4713.5), (398, 3972.1666666666665), (478, 4067.4545454545455), (6, 6578.1), (572, 4506.625), (826, 5632.428571428572), (308, 5895.818181818182), (264, 4761.6), (112, 5224.153846153846), (860, 5363.333333333333), (42, 4913.928571428572), (236, 2571.4444444444443), (868, 5481.571428571428), (110, 5016.7692307692305), (430, 4335.181818181818), (18, 5145.888888888889), (428, 6346.636363636364), (988, 5109.454545454545), (182, 5437.625), (788, 5687.111111111111), (234, 3592.5), (502, 5064.375), (726, 4297.583333333333), (728, 4653.666666666667), (804, 4788.25), (54, 5043.384615384615), (500, 5148.0625), (998, 3726.5714285714284), (434, 5670.0), (596, 5245.7692307692305), (486, 5187.615384615385), (994, 3085.7), (266, 4032.9375), (312, 4274.1), (90, 3873.9375), (680, 5328.454545454545), (834, 4953.076923076923), (648, 4910.0), (636, 5030.636363636364), (552, 4110.692307692308), (628, 5439.285714285715), (694, 4302.9), (984, 4980.375), (208, 6116.416666666667), (720, 4173.2), (422, 5096.9), (844, 4487.461538461538), (448, 5218.454545454545), (330, 3911.5555555555557), (714, 5301.2), (186, 4688.5), (326, 5135.181818181818), (842, 4537.846153846154), (358, 5463.615384615385), (228, 4888.571428571428), (338, 4804.0), (566, 2128.1428571428573), (506, 5807.714285714285), (560, 5318.0), (690, 5429.923076923077), (610, 4407.090909090909), (366, 4765.714285714285), (504, 4818.6), (460, 5035.142857142857), (496, 4206.294117647059), (412, 6438.5), (748, 5837.8), (562, 6019.090909090909), (62, 5301.46153 ...

# %%
# Compare the results
groupByKey_dict = dict(averages_groupByKey_result)
reduceByKey_dict = dict(averages_reduceByKey_result)

comparison = [(key, groupByKey_dict[key], reduceByKey_dict[key]) for key in groupByKey_dict if groupByKey_dict[key] != reduceByKey_dict[key]]

if not comparison:
    print("The results are the same.")
else:
    print("Differences found:", comparison)
# Out:
# The results are the same.
